# %% [markdown]
# ### Data Source

# %% [markdown]
# https://www.kaggle.com/vipoooool/new-plant-diseases-dataset

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# I will build a classification model to classify whether a plant is healthy or unhealthy. The guiding metric will be accuracy.
#
# The goal is to help plant owners determine when their plants need special attention, ie. over/under watering, too much/too little sunlight, or pests.

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# 1) Organize images into two directories: healthy (20K images) and diseased (20K images).

# %% [markdown]
# 2) Sample a smaller dataset, possibly 500 healthy and 500 diseased

# %% [markdown]
# 3) Resize images, convert to array

# %% [markdown]
# ### Models

# %% [markdown]
# CNN

# %% [markdown]
# ### Assumptions

# %% [markdown]
# The training data is images of crop leaves (ie. apples, corn) but the goal is to be able to use the model to predict on houseplants.

# %% [markdown]
# ### EDA

# %%
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# %% [markdown]
# Healthy

# %%
load_img('Data/Healthy/000146ff-92a4-4db6-90ad-8fce2ae4fddd___GH_HL Leaf 259.1.JPG')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FB81A359BD0>

# %% [markdown]
# Diseased

# %%
load_img('Data/Diseased/0001aa74-bbd7-433b-a900-1dccab39d521___FAM_L.Blight 4508_flipLR.JPG')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FB818D75350>
