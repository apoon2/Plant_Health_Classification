# %% [markdown]
# ### Data Source

# %% [markdown]
# https://www.kaggle.com/vipoooool/new-plant-diseases-dataset
#
# https://www.kaggle.com/russellchan/healthy-and-wilted-houseplant-images/version/1?select=houseplant_images
#
# https://www.reddit.com/r/plantclinic/

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# I will build an image classification model to determine whether a plant is healthy or unhealthy. The guiding metric will be accuracy.
#
# The goal is to help plant owners determine when their plants need special attention, ie. over/under watering, too much/too little sunlight, or pests.

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# 1a) Organize crop images into two directories: healthy (20K images) and diseased (20K images).
#
# 1b) Organize houseplant images into two directories: healthy (451 images) and wilted (451 images).

# %% [markdown]
# 2) Sample a smaller dataset, possibly 951 healthy (500 crop, 451 houseplant) and 951 diseased (500 crop, 451 houseplant)

# %% [markdown]
# 3) Resize images, convert to array

# %% [markdown]
# ### Models

# %% [markdown]
# CNN
#
# YOLO

# %% [markdown]
# ### Assumptions

# %% [markdown]
# The training data is mostly images of crop leaves (ie. apples, corn) but the goal is to be able to use the model to predict on houseplants.

# %% [markdown]
# ### EDA

# %%
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# %% [markdown]
# Healthy

# %%
load_img('Data/crop_images/healthy/000146ff-92a4-4db6-90ad-8fce2ae4fddd___GH_HL Leaf 259.1.JPG')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FC0A052E490>

# %%
load_img('Data/houseplant_images/healthy/healthy_000.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1735x1727 at 0x7FC0800EC350>

# %% [markdown]
# Diseased

# %%
load_img('Data/crop_images/diseased/0001aa74-bbd7-433b-a900-1dccab39d521___FAM_L.Blight 4508_flipLR.JPG')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FC092868E50>

# %%
load_img('Data/houseplant_images/wilted/wilted_000.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x853 at 0x7FC0800ECB90>
